# %%
import numpy as np
import pandas as pd

# %%
numbers=np.random.randint(0,10,50)
snumbers=pd.Series(numbers)

# %%
snumbers.value_counts().sort_index()
# Out:
# 0    6
# 1    8
# 2    3
# 3    6
# 4    4
# 5    2
# 6    6
# 7    3
# 8    7
# 9    5
# Name: count, dtype: int64
